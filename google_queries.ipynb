# %%
import google
for url in google.search("site:vk.com"):
    print url
# Out:
# https://vk.com/
# https://vk.com/agniaogonek
# https://vk.com/the_kayascodelario
# https://vk.com/id346461033
# https://vk.com/kevinspacey
# https://vk.com/id305962615
# https://vk.com/kostya_zzz
# https://vk.com/club93405003
# https://vk.com/dizzydizaster
# https://vk.com/ru9gag
# https://vk.com/queen_bey
# https://vk.com/narod_protiv
# https://vk.com/djsmokeyexclusive
# https://vk.com/stern_survivalist
# https://vk.com/fomichevlev
# https://vk.com/id256031932
# https://vk.com/rbc
# https://vk.com/id315971715
# https://vk.com/sashapolubinskii
# https://vk.com/tylerleehoechlin
# https://vk.com/durov
# https://vk.com/id401549326
# https://vk.com/id260404271
# https://vk.com/mil
# https://vk.com/mirperedel
# https://vk.com/id298582641
# https://vk.com/live
# https://vk.com/id112985556
# https://vk.com/nassson
# https://vk.com/justinchon
# https://vk.com/basimbashir
# https://vk.com/id353899012
# http://vk.com/id128885716
# https://vk.com/republicr
# ...
